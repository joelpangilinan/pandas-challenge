# %%
# Hong Kong LPG Appliances
# In this activity, you will take an LPG appliance dataset from Hong Kong, and clean it up so that the DataFrame is consistent and does not have any rows with missing data.
# Instructions
# Read in the CSV using Pandas, and print out the DataFrame that is returned.
# Note:** This dataset uses Chinese characters and should be read in using UTF-8 encoding.
# Reduce the DataFrame to only the columns in English.
# Get a count of the rows within the DataFrame to determine if there are any null values.
# Drop the rows that contain null values.
# Search through the "Applicant" column, and replace any similar values with one consistent value.
# Create a couple DataFrames that look into one Place of Manufacture only, and print them to the screen.

# %%
# Import Dependencies
import pandas as pd

# %%
# Reference the file where the CSV is located
lpg_file = "../Resources/dga_lpg.csv"

# Import the data into a Pandas DataFrame
lpg_df = pd.read_csv(lpg_file, encoding="utf-8")
lpg_df.head()
# Out:
#                                                 Part  \
# 0  Part 1 – Approved Domestic Gas Cooking Appliances
# 1  Part 1 – Approved Domestic Gas Cooking Appliances
# 2  Part 1 – Approved Domestic Gas Cooking Appliances
# 3  Part 1 – Approved Domestic Gas Cooking Appliances
# 4  Part 1 – Approved Domestic Gas Cooking Appliances
#
#                          Type    Type.1        Brand    牌子      Model  \
# 0  Built-in Hotplate 1 Burner  嵌入式單頭平面爐  De Dietrich   NaN  DTG1288XC
# 1  Built-in Hotplate 1 Burner  嵌入式單頭平面爐   Electrolux  伊萊克斯   EGC-2901
# 2  Built-in Hotplate 1 Burner  嵌入式單頭平面爐     Gaggenau   NaN  VG231120F
# 3  Built-in Hotplate 1 Burner  嵌入式單頭平面爐     Gaggenau   NaN  VG231114F
# 4  Built-in Hotplate 1 Burner  嵌入式單頭平面爐  GERMAN POOL   德國寶  GP12-1-LG
#
#            Other Information    其他資料            Place of Manufacture     製造地點  \
# 0    CERAMIC GLASS TOP PANEL  陶瓷玻璃面版                           Italy      意大利
# 1    CERAMIC GLASS TOP PANEL  陶瓷玻璃面版  The People's Republic of China  中華人民共和國
# 2  STAINLESS STEEL TOP PANEL   不銹鋼面版                          France       法國
# 3  STAINLESS STEEL TOP PANEL   不銹鋼面版                          France       法國
# 4            GLASS TOP PANEL    玻璃面版  The People's Republic of China  中華人民共和國
#
#                       Applicant                          申請人 Telephone Number  \
# 0          Gilman Group Limited                   太平洋行國際有限公司        2418 3272
# 1          Dah Chong Hong, Ltd.                    大昌貿易行有限公司        2262 1690
# 2   Kitchen Infinity Corp. Ltd.  Kitchen Infinity Corp. Ltd.        2552 2208
# 3   Kitchen Infinity Corp. Ltd.  Kitchen Infinity Corp. Ltd.        2552 2208
# 4  German Pool (Hong Kong) Ltd.                  德國寶（香港）有限公司        2773 2812
#
#   Approval Expiry Date
# 0           2023-09-26
# 1           2024-06-24
# 2           2024-04-01
# 3           2022-07-19
# 4           2025-02-15

# %%
# Reduce to columns that are in English
lpg_reduced_df = lpg_df[["Part","Type","Brand","Model","Other Information","Place of Manufacture","Applicant","Telephone Number","Approval Expiry Date"]]
lpg_reduced_df.head()
# Out:
#                                                 Part  \
# 0  Part 1 – Approved Domestic Gas Cooking Appliances
# 1  Part 1 – Approved Domestic Gas Cooking Appliances
# 2  Part 1 – Approved Domestic Gas Cooking Appliances
# 3  Part 1 – Approved Domestic Gas Cooking Appliances
# 4  Part 1 – Approved Domestic Gas Cooking Appliances
#
#                          Type        Brand      Model  \
# 0  Built-in Hotplate 1 Burner  De Dietrich  DTG1288XC
# 1  Built-in Hotplate 1 Burner   Electrolux   EGC-2901
# 2  Built-in Hotplate 1 Burner     Gaggenau  VG231120F
# 3  Built-in Hotplate 1 Burner     Gaggenau  VG231114F
# 4  Built-in Hotplate 1 Burner  GERMAN POOL  GP12-1-LG
#
#            Other Information            Place of Manufacture  \
# 0    CERAMIC GLASS TOP PANEL                           Italy
# 1    CERAMIC GLASS TOP PANEL  The People's Republic of China
# 2  STAINLESS STEEL TOP PANEL                          France
# 3  STAINLESS STEEL TOP PANEL                          France
# 4            GLASS TOP PANEL  The People's Republic of China
#
#                       Applicant Telephone Number Approval Expiry Date
# 0          Gilman Group Limited        2418 3272           2023-09-26
# 1          Dah Chong Hong, Ltd.        2262 1690           2024-06-24
# 2   Kitchen Infinity Corp. Ltd.        2552 2208           2024-04-01
# 3   Kitchen Infinity Corp. Ltd.        2552 2208           2022-07-19
# 4  German Pool (Hong Kong) Ltd.        2773 2812           2025-02-15

# %%
# look for missing values
lpg_reduced_df.count()
# Out:
# Part                    939
# Type                    939
# Brand                   939
# Model                   939
# Other Information       936
# Place of Manufacture    939
# Applicant               939
# Telephone Number        939
# Approval Expiry Date    939
# dtype: int64

# %%
# drop null rows
lpg_drop_rows_df = lpg_reduced_df.dropna(how="any")

# %%
# verify counts
lpg_drop_rows_df.count()
# Out:
# Part                    936
# Type                    936
# Brand                   936
# Model                   936
# Other Information       936
# Place of Manufacture    936
# Applicant               936
# Telephone Number        936
# Approval Expiry Date    936
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Applicant"
#list(lpg_drop_rows_df["Applicant"])
lpg_drop_rows_df["Applicant"].unique()
# Out:
# array(['Gilman Group Limited', 'Dah Chong Hong, Ltd.',
#        'Kitchen Infinity Corp. Ltd.', 'German Pool (Hong Kong) Ltd.',
#        'World Engineering Limited', 'Hibachi Gas Cooker Limited',
#        'Whirlpool (Hong Kong) Ltd.', 'Miele (Hong Kong) Limited',
#        'Dong Woo Industrial Co. Ltd.', 'BSH Home Appliances Ltd.',
#        'The Union Gas Appliances (Holdings) Ltd.',
#        'Whampo Trading Limited', 'Sunny Eternal Limited',
#        'Toptech Co. Limited', 'D & A Electronics Co., Ltd.',
#        'Fidelity (Far East) Trading Co., Ltd.',
#        'Araytron Technology Limited', 'Charm Vantage Limited',
#        'Lighting Gas Stoves Trading Ltd', 'Lighting (Japan) Trading Ltd.',
#        'Homepro International Limited',
#        'The Hong Kong & China Gas Co., Ltd.',
#        'Energy Trading Company Limited',
#        'Wealthy Link International Trading Limited',
#        'Wetol Company Limited',
#        'Crown Gas Stoves (Holdings) Company Limited',
#        'Iwatani Corporation (Hong Kong) Limited',
#        'Sun Kee LP Gas Co. Limited', 'Baumatic Asia Limited',
#        'Great Treasure International Ltd.', 'Chuen Kwong Hong Ltd',
#        'Shun Hing Electric Works & Engineering Co., Ltd.',
#        'Vocci Group Limited', 'Wing Hing Electrical Engineers Co., Ltd.',
#        'Nasim Engineering Trading Co.',
#        'Kelvin Electric Trading Co. Ltd.', 'Crown Gas Stoves Co., Ltd.',
#        'Sunrise Enterprise HK Limited',
#        'Alliance Ascent Holdings Limited',
#        'Famous International (H.K.) Ltd.', 'Gastar Group Company Limited',
#        'Hong Kong L.P. Gas (Holdings) Ltd.', 'Alpha Appliances Ltd',
#        'Tai Cheong International Trading Limited',
#        'Excellent Industry (Hong Kong) Limited', 'Federal Supplier Ltd.',
#        'Wai Bong Electrical Trading Co. Ltd.',
#        'General Appliance (H.K.) Ltd.', 'K & K Trading (H.K) Limited',
#        'California Heavy Industries Limited', 'Vatti (H.K.) Limited',
#        'Westwing Appliances Ltd.', 'Madison (Hong Kong) Limited',
#        'Bright Gas Appliances Co., Ltd.', 'Teka China Ltd.',
#        'Best Joint International Trading Co., Ltd.',
#        'Silver Star International Ltd.',
#        'Sun Hing Gas Household Utensils Co., Ltd.',
#        'A & P International Ltd', 'Fung Lee (Asia) Limited',
#        'Nan Kee Trading Co., Ltd.', 'Lung Shing Cheung Hop Kee',
#        'Sun Kee LP Gas Co.', 'Hop Hing Co.',
#        'Fortress - Adivision of A.S. Watson Group (HK) Ltd.',
#        'Perfect Gas Stoves Trading & Engineering Ltd.',
#        'GMG International co. Ltd.', 'Jebsen & Co., Ltd.',
#        'Tops Company Limited', 'Wintex Asia Enterprise Ltd.',
#        'Hotpool Industries Limited'], dtype=object)

# %%
# Combine similar applicants together
lpg_combined_applicants_df = lpg_drop_rows_df.replace(
    {"Crown Gas Stoves (Holdings) Company Limited": "Crown Gas Stoves Co., Ltd.", 
     "Sun Kee LP Gas Co.": "Sun Kee LP Gas Co. Limited"})
lpg_combined_applicants_df.head()
# Out:
#                                                 Part  \
# 0  Part 1 – Approved Domestic Gas Cooking Appliances
# 1  Part 1 – Approved Domestic Gas Cooking Appliances
# 2  Part 1 – Approved Domestic Gas Cooking Appliances
# 3  Part 1 – Approved Domestic Gas Cooking Appliances
# 4  Part 1 – Approved Domestic Gas Cooking Appliances
#
#                          Type        Brand      Model  \
# 0  Built-in Hotplate 1 Burner  De Dietrich  DTG1288XC
# 1  Built-in Hotplate 1 Burner   Electrolux   EGC-2901
# 2  Built-in Hotplate 1 Burner     Gaggenau  VG231120F
# 3  Built-in Hotplate 1 Burner     Gaggenau  VG231114F
# 4  Built-in Hotplate 1 Burner  GERMAN POOL  GP12-1-LG
#
#            Other Information            Place of Manufacture  \
# 0    CERAMIC GLASS TOP PANEL                           Italy
# 1    CERAMIC GLASS TOP PANEL  The People's Republic of China
# 2  STAINLESS STEEL TOP PANEL                          France
# 3  STAINLESS STEEL TOP PANEL                          France
# 4            GLASS TOP PANEL  The People's Republic of China
#
#                       Applicant Telephone Number Approval Expiry Date
# 0          Gilman Group Limited        2418 3272           2023-09-26
# 1          Dah Chong Hong, Ltd.        2262 1690           2024-06-24
# 2   Kitchen Infinity Corp. Ltd.        2552 2208           2024-04-01
# 3   Kitchen Infinity Corp. Ltd.        2552 2208           2022-07-19
# 4  German Pool (Hong Kong) Ltd.        2773 2812           2025-02-15

# %%
# Check to see if you combined similar applicants correctly in "Applicant"
lpg_combined_applicants_df["Applicant"].unique()
# Out:
# array(['Gilman Group Limited', 'Dah Chong Hong, Ltd.',
#        'Kitchen Infinity Corp. Ltd.', 'German Pool (Hong Kong) Ltd.',
#        'World Engineering Limited', 'Hibachi Gas Cooker Limited',
#        'Whirlpool (Hong Kong) Ltd.', 'Miele (Hong Kong) Limited',
#        'Dong Woo Industrial Co. Ltd.', 'BSH Home Appliances Ltd.',
#        'The Union Gas Appliances (Holdings) Ltd.',
#        'Whampo Trading Limited', 'Sunny Eternal Limited',
#        'Toptech Co. Limited', 'D & A Electronics Co., Ltd.',
#        'Fidelity (Far East) Trading Co., Ltd.',
#        'Araytron Technology Limited', 'Charm Vantage Limited',
#        'Lighting Gas Stoves Trading Ltd', 'Lighting (Japan) Trading Ltd.',
#        'Homepro International Limited',
#        'The Hong Kong & China Gas Co., Ltd.',
#        'Energy Trading Company Limited',
#        'Wealthy Link International Trading Limited',
#        'Wetol Company Limited', 'Crown Gas Stoves Co., Ltd.',
#        'Iwatani Corporation (Hong Kong) Limited',
#        'Sun Kee LP Gas Co. Limited', 'Baumatic Asia Limited',
#        'Great Treasure International Ltd.', 'Chuen Kwong Hong Ltd',
#        'Shun Hing Electric Works & Engineering Co., Ltd.',
#        'Vocci Group Limited', 'Wing Hing Electrical Engineers Co., Ltd.',
#        'Nasim Engineering Trading Co.',
#        'Kelvin Electric Trading Co. Ltd.',
#        'Sunrise Enterprise HK Limited',
#        'Alliance Ascent Holdings Limited',
#        'Famous International (H.K.) Ltd.', 'Gastar Group Company Limited',
#        'Hong Kong L.P. Gas (Holdings) Ltd.', 'Alpha Appliances Ltd',
#        'Tai Cheong International Trading Limited',
#        'Excellent Industry (Hong Kong) Limited', 'Federal Supplier Ltd.',
#        'Wai Bong Electrical Trading Co. Ltd.',
#        'General Appliance (H.K.) Ltd.', 'K & K Trading (H.K) Limited',
#        'California Heavy Industries Limited', 'Vatti (H.K.) Limited',
#        'Westwing Appliances Ltd.', 'Madison (Hong Kong) Limited',
#        'Bright Gas Appliances Co., Ltd.', 'Teka China Ltd.',
#        'Best Joint International Trading Co., Ltd.',
#        'Silver Star International Ltd.',
#        'Sun Hing Gas Household Utensils Co., Ltd.',
#        'A & P International Ltd', 'Fung Lee (Asia) Limited',
#        'Nan Kee Trading Co., Ltd.', 'Lung Shing Cheung Hop Kee',
#        'Hop Hing Co.',
#        'Fortress - Adivision of A.S. Watson Group (HK) Ltd.',
#        'Perfect Gas Stoves Trading & Engineering Ltd.',
#        'GMG International co. Ltd.', 'Jebsen & Co., Ltd.',
#        'Tops Company Limited', 'Wintex Asia Enterprise Ltd.',
#        'Hotpool Industries Limited'], dtype=object)

# %%
# Create a new DataFrame that looks into a specific Place of Manufacture
lpg_manu_df = lpg_combined_applicants_df.loc[lpg_combined_applicants_df["Place of Manufacture"] == "Italy"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lpg_combined_applicants_df'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16060\119673414.py in <module>
#       1 # Create a new DataFrame that looks into a specific Place of Manufacture
# ----> 2 lpg_combined_applicants_df["lpg_combined_applicants_df"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'lpg_combined_applicants_df'

# %%
portugal_products_df = no_null_lpg_df.loc[no_null_lpg_df["Place of Manufacture"] == "Portugal"]
portugal_products_df
